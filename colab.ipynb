# %%
# !git clone https://github.com/NNlk05/slimechunks.git
# Out:
# Cloning into 'slimechunks'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 39 (delta 18), reused 36 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 8.48 KiB | 2.12 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# !cd slimechunks && make slime_finder
# Out:
# make: 'slime_finder' is up to date.

# %%
# !cd slimechunks && ./slime_finder
# Out:
# Error: Could not open likely_locations.txt
